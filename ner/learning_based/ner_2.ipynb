# %%
import json
import random
import spacy
from spacy.util import minibatch, compounding
from pathlib import Path
from tqdm import tqdm
from spacy.training.example import Example
def remove_overlapping_entities(data):
    cleaned_data = []

    for text, annot in data:
        entities = sorted(annot["entities"], key=lambda x: x[0])  # sort by start
        filtered = []
        last_end = -1
        for start, end, label in entities:
            if start >= last_end:
                filtered.append([start, end, label])
                last_end = end
        cleaned_data.append((text, {"entities": filtered}))

    return cleaned_data
# Load training data
with open("train_data.json", "r", encoding="utf-8") as f:
    TRAIN_DATA = json.load(f)

# Load base model (can use en_core_web_md or lg too)
nlp = spacy.load("en_core_web_sm")
ner = nlp.get_pipe("ner")

# Add the custom label
LABEL = "INGREDIENT"
ner.add_label(LABEL)

# Disable other pipeline components
pipe_exceptions = ["ner"]
unaffected_pipes = [pipe for pipe in nlp.pipe_names if pipe not in pipe_exceptions]
TRAIN_DATA = remove_overlapping_entities(TRAIN_DATA)

# Start training
with nlp.disable_pipes(*unaffected_pipes):
    optimizer = nlp.resume_training()
    n_iter = 10

    for itn in range(n_iter):
        print(f"Iteration {itn + 1}")
        random.shuffle(TRAIN_DATA)
        losses = {}
        batches = minibatch(TRAIN_DATA, size=compounding(4.0, 32.0, 1.5))

        for batch in batches:
            examples = []
            for text, annots in batch:
                doc = nlp.make_doc(text)
                example = Example.from_dict(doc, annots)
                examples.append(example)

            nlp.update(examples, drop=0.3, losses=losses)
        print("Losses:", losses)
# Save the trained model
output_dir = Path("ingredient_ner_model")
output_dir.mkdir(exist_ok=True)
nlp.to_disk(output_dir)
print(f"Model saved to {output_dir}")
# Out:
# Iteration 1
# /usr/local/lib/python3.11/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "To begin with Potato Puff Pastry, In a mixing bowl..." with entities "[[14, 20, 'INGREDIENT'], [69, 74, 'INGREDIENT'], [...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "To begin making Bottle Gourd Ice Cream Recipe -Lau..." with entities "[[16, 28, 'INGREDIENT'], [47, 52, 'INGREDIENT'], [...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "We begin making Besan Barfi Recipe, in a deep non ..." with entities "[[16, 21, 'INGREDIENT'], [73, 77, 'INGREDIENT'], [...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "To begin making Chatpata Lobia Chaat Recipe, soak ..." with entities "[[25, 30, 'INGREDIENT'], [54, 70, 'INGREDIENT'], [...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "To begin making Chettinad Style Puliyogare Gojju R..." with entities "[[221, 230, 'INGREDIENT'], [274, 285, 'INGREDIENT'...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "To begin with Broccoli Paneer And Peanut Masala, h..." with entities "[[114, 119, 'INGREDIENT'], [233, 240, 'INGREDIENT'...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "To begin making the Rajasthani Hari Mirch Ka Maas ..." with entities "[[85, 99, 'INGREDIENT'], [115, 129, 'INGREDIENT'],...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "To begin making Karwar Style Madgane Recipe With O..." with entities "[[86, 91, 'INGREDIENT'], [192, 197, 'INGREDIENT'],...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "To begin making the Turai Moong Dal Recipe, first ..." with entities "[[148, 152, 'INGREDIENT'], [157, 172, 'INGREDIENT'...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "To begin making the Kori Gassi Recipe,  wash and c..." with entities "[[134, 138, 'INGREDIENT'], [278, 282, 'INGREDIENT'...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "To begin making the Kurkuri Bhindi With Spicy Toma..." with entities "[[28, 34, 'INGREDIENT'], [46, 52, 'INGREDIENT'], [...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "To begin making the Chilli Ginger Vegetable Tofu s..." with entities "[[27, 33, 'INGREDIENT'], [148, 163, 'INGREDIENT'],...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "To make this Karnataka style ripe mango curry, was..." with entities "[[29, 33, 'INGREDIENT'], [34, 39, 'INGREDIENT'], [...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "To begin making the Kadai Vegetable Sabzi, we will..." with entities "[[497, 503, 'INGREDIENT'], [524, 532, 'INGREDIENT'...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "To begin making the Punjabi Style Lobia Masala rec..." with entities "[[34, 39, 'INGREDIENT'], [83, 94, 'INGREDIENT'], [...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "To Begin making the Vazhaipoo Podimas/ Poriyal Rec..." with entities "[[20, 29, 'INGREDIENT'], [70, 83, 'INGREDIENT'], [...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "To begin making the Baked Stuffed Baati With Churm..." with entities "[[147, 158, 'INGREDIENT'], [173, 177, 'INGREDIENT'...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "To begin making Ukadpendi, first whisk the butterm..." with entities "[[43, 53, 'INGREDIENT'], [63, 73, 'INGREDIENT'], [...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "To begin making the Vaangi Bhaat recipe, first was..." with entities "[[65, 69, 'INGREDIENT'], [366, 379, 'INGREDIENT'],...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "To begin making Lauki Ka Salan Recipe prep all the..." with entities "[[16, 21, 'INGREDIENT'], [114, 121, 'INGREDIENT'],...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "To begin making the Mushroom Strudel Recipe, we wi..." with entities "[[128, 137, 'INGREDIENT'], [293, 299, 'INGREDIENT'...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "To begin making Passion Fruit- Shrikhand Shots Rec..." with entities "[[16, 29, 'INGREDIENT'], [127, 131, 'INGREDIENT'],...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "To begin making the Chap Badami recipe, for the ma..." with entities "[[196, 200, 'INGREDIENT'], [324, 328, 'INGREDIENT'...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "To begin making the Milagu Jeera Sadam Recipe With..." with entities "[[27, 32, 'INGREDIENT'], [51, 63, 'INGREDIENT'], [...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "To begin making this Sweet And Spicy Tofu Salad Wi..." with entities "[[53, 61, 'INGREDIENT'], [421, 437, 'INGREDIENT'],...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "To begin making Chatpate Aloo Recipe With Sesame S..." with entities "[[42, 54, 'INGREDIENT'], [69, 82, 'INGREDIENT'], [...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "To begin making the Nimki Aloo Anardana Curry reci..." with entities "[[26, 30, 'INGREDIENT'], [108, 113, 'INGREDIENT'],...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "To begin making the Thulli recipe, mix lukewarm mi..." with entities "[[48, 52, 'INGREDIENT'], [153, 157, 'INGREDIENT'],...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "To begin making the Carrot Idli recipe, wash the c..." with entities "[[20, 26, 'INGREDIENT'], [49, 55, 'INGREDIENT'], [...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "To begin making your Nadru Ke Kabab, in a pressure..." with entities "[[73, 79, 'INGREDIENT'], [81, 87, 'INGREDIENT'], [...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "To begin making Assamese Narasingh Masor Jhol Reci..." with entities "[[62, 67, 'INGREDIENT'], [284, 295, 'INGREDIENT'],...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "To begin with, the Amritsari Chole Recipe, first p..." with entities "[[106, 118, 'INGREDIENT'], [241, 245, 'INGREDIENT'...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "To begin making Methi Chaman Recipe -Paneer In Dar..." with entities "[[37, 43, 'INGREDIENT'], [98, 103, 'INGREDIENT'], ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "To begin making S'mores Cake Recipe, prep up all t..." with entities "[[210, 216, 'INGREDIENT'], [218, 229, 'INGREDIENT'...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "To begin making Subway Sandwich Recipe With Roaste..." with entities "[[52, 60, 'INGREDIENT'], [171, 175, 'INGREDIENT'],...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "To begin making Easy Homemade Sugar Free Dates Fla..." with entities "[[41, 46, 'INGREDIENT'], [77, 82, 'INGREDIENT'], [...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "To begin making Jhinga Gawar Recipe -Shrimps & Clu..." with entities "[[37, 44, 'INGREDIENT'], [164, 175, 'INGREDIENT'],...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "To begin making the Matar Karanji first make the d..." with entities "[[109, 114, 'INGREDIENT'], [126, 130, 'INGREDIENT'...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "To begin making Makai Ka Cheela Recipe, peel the c..." with entities "[[151, 161, 'INGREDIENT'], [232, 237, 'INGREDIENT'...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "To begin making the Anda Ghotala Recipe, melt butt..." with entities "[[46, 52, 'INGREDIENT'], [86, 92, 'INGREDIENT'], [...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "To begin making the Banana Cream Pie, first make t..." with entities "[[109, 114, 'INGREDIENT'], [116, 122, 'INGREDIENT'...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "To prepare Mixed Sprouts Curry Recipe, get ready w..." with entities "[[331, 342, 'INGREDIENT'], [347, 357, 'INGREDIENT'...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "To begin making the Sweet Corn And Capsicum Curry ..." with entities "[[20, 30, 'INGREDIENT'], [35, 43, 'INGREDIENT'], [...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "To prepare Potato Stuffed Dal Dhokli Recipe, get p..." with entities "[[11, 17, 'INGREDIENT'], [162, 166, 'INGREDIENT'],...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "To prepare Apple Carrot Sweet Potato Soup With Gar..." with entities "[[11, 16, 'INGREDIENT'], [17, 23, 'INGREDIENT'], [...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "To begin making the Boti Masala Chaat Recipe, cut ..." with entities "[[197, 202, 'INGREDIENT'], [213, 217, 'INGREDIENT'...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "To begin making the Kumror Chokka Recipe, prep all..." with entities "[[98, 108, 'INGREDIENT'], [163, 167, 'INGREDIENT']...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "To prepare Awadhi Khaas Nihari Recipe, firstly slo..." with entities "[[58, 63, 'INGREDIENT'], [79, 90, 'INGREDIENT'], [...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "To prepare Utanki (Crispy Rice Crepes Recipe) get ..." with entities "[[110, 120, 'INGREDIENT'], [122, 127, 'INGREDIENT'...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "To begin making Poondu Milagu Kuzhambu Recipe, soa..." with entities "[[56, 64, 'INGREDIENT'], [163, 169, 'INGREDIENT'],...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "To prepare Instant Tindora & Carrot Pickle Recipe,..." with entities "[[19, 26, 'INGREDIENT'], [29, 35, 'INGREDIENT'], [...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "To begin making the Sprouted Moong And Methi Pulao..." with entities "[[93, 106, 'INGREDIENT'], [139, 150, 'INGREDIENT']...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "To Begin making the Sweet Corn, Methi & Tomato Ric..." with entities "[[20, 30, 'INGREDIENT'], [40, 46, 'INGREDIENT'], [...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "To begin making the Mor Milagai, first wash the gr..." with entities "[[48, 62, 'INGREDIENT'], [292, 296, 'INGREDIENT'],...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "To begin making the South Indian Style Sorakkai Ko..." with entities "[[62, 74, 'INGREDIENT'], [132, 144, 'INGREDIENT'],...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "To begin making the Curry Leaves Buttermilk Recipe..." with entities "[[61, 65, 'INGREDIENT'], [105, 109, 'INGREDIENT'],...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "To begin making Fusion Style Paneer Malai Makhani ..." with entities "[[29, 35, 'INGREDIENT'], [122, 133, 'INGREDIENT'],...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "To begin making the Turmeric Latte Recipe, take a ..." with entities "[[96, 111, 'INGREDIENT'], [209, 222, 'INGREDIENT']...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "To begin making Mangalorean Mavinakayi Menasinakai..." with entities "[[83, 88, 'INGREDIENT'], [174, 179, 'INGREDIENT'],...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "To begin making the Peerkangai Thogayal recipe, wa..." with entities "[[219, 232, 'INGREDIENT'], [265, 275, 'INGREDIENT'...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "For making Kheer Puli Pitha | Bengali Pitha Recipe..." with entities "[[117, 127, 'INGREDIENT'], [144, 148, 'INGREDIENT'...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "To begin making Watalappan Recipe, grate the jagge..." with entities "[[45, 52, 'INGREDIENT'], [85, 92, 'INGREDIENT'], [...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "To begin making the Kondai Kadalai Puli Kuzhambu R..." with entities "[[105, 110, 'INGREDIENT'], [233, 238, 'INGREDIENT'...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Method To make the doughPrepare the dough by mixin..." with entities "[[72, 76, 'INGREDIENT'], [86, 92, 'INGREDIENT'], [...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "To begin making the Chole Masala Biryani Recipe, l..." with entities "[[512, 516, 'INGREDIENT'], [532, 547, 'INGREDIENT'...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "To begin making the Vegetable Handvo recipe, soak ..." with entities "[[111, 115, 'INGREDIENT'], [353, 358, 'INGREDIENT'...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "To begin making Homemade Mysore Pak Recipe, prep a..." with entities "[[443, 448, 'INGREDIENT'], [450, 460, 'INGREDIENT'...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "To begin making Pyaz Wali Bhindi Recipe Bhindi Do ..." with entities "[[26, 32, 'INGREDIENT'], [40, 46, 'INGREDIENT'], [...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "To begin making the Herbed Brown Rice Recipe, soak..." with entities "[[27, 37, 'INGREDIENT'], [55, 65, 'INGREDIENT'], [...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Baked Chinese Potato Recipe also called Koorka Mez..." with entities "[[6, 20, 'INGREDIENT'], [241, 255, 'INGREDIENT'], ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "To begin making the Heart Shaped Tea Sandwiches re..." with entities "[[158, 165, 'INGREDIENT'], [167, 186, 'INGREDIENT'...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "To begin making Sorakkai Kozhukattai Paal Kuzhambu..." with entities "[[67, 76, 'INGREDIENT'], [92, 97, 'INGREDIENT'], [...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "To begin making the Kashmiri Saffron Fennel Rice R..." with entities "[[44, 48, 'INGREDIENT'], [97, 101, 'INGREDIENT'], ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "To begin making the Layered Paneer Butter Masala B..." with entities "[[83, 87, 'INGREDIENT'], [91, 96, 'INGREDIENT'], [...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "To begin making the Paneer Gassi Recipe, soak the ..." with entities "[[20, 26, 'INGREDIENT'], [134, 138, 'INGREDIENT'],...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "To begin making the Yeruvalli Kuzhambu/ Iru Puli K..." with entities "[[160, 174, 'INGREDIENT'], [231, 245, 'INGREDIENT'...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "To begin making Chicken Manchurian Recipe, in a mi..." with entities "[[16, 23, 'INGREDIENT'], [90, 99, 'INGREDIENT'], [...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "To begin making the Turmeric Milk (Haldi Doodh), b..." with entities "[[29, 33, 'INGREDIENT'], [91, 95, 'INGREDIENT'], [...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "To prepare Herbed Muffins With Cheese Recipe, preh..." with entities "[[134, 139, 'INGREDIENT'], [147, 160, 'INGREDIENT'...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "To begin making the Aloo Gobi Kathi Roll, we have ..." with entities "[[25, 29, 'INGREDIENT'], [77, 81, 'INGREDIENT'], [...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "To prepare Murg Malai Kebab Recipe (Reshmi Kebab),..." with entities "[[180, 199, 'INGREDIENT'], [200, 219, 'INGREDIENT'...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "To begin making the Rajasthani Daal Baaple Churma ..." with entities "[[110, 121, 'INGREDIENT'], [136, 140, 'INGREDIENT'...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "To start preparing for Sabuana Sandige | Fryums Re..." with entities "[[61, 69, 'INGREDIENT'], [80, 85, 'INGREDIENT'], [...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "To begin making the Mangsher Jhol recipe, wash the..." with entities "[[51, 57, 'INGREDIENT'], [99, 105, 'INGREDIENT'], ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "To prepare Penne Pasta In White Sauce Recipe, heat..." with entities "[[11, 22, 'INGREDIENT'], [84, 88, 'INGREDIENT'], [...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "To begin making Palak Lobia Curry Recipe/ Keerai K..." with entities "[[16, 21, 'INGREDIENT'], [22, 27, 'INGREDIENT'], [...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "To begin making the Pudina Sooji & Oats Dhokla Rec..." with entities "[[20, 26, 'INGREDIENT'], [27, 32, 'INGREDIENT'], [...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "To begin making Caramel Plum Cake Recipe, soak all..." with entities "[[296, 301, 'INGREDIENT'], [504, 509, 'INGREDIENT'...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "To begin making the Pavakkai Poriyal Recipe, we wi..." with entities "[[88, 94, 'INGREDIENT'], [160, 175, 'INGREDIENT'],...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "To begin making Doodhi Sabudana Kheer Recipe, wash..." with entities "[[23, 31, 'INGREDIENT'], [115, 120, 'INGREDIENT'],...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "To begin making the Yogurt Lamb Curry recipe, firs..." with entities "[[27, 31, 'INGREDIENT'], [81, 86, 'INGREDIENT'], [...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "To begin making the Spiced Apple Crumble Recipe wi..." with entities "[[53, 65, 'INGREDIENT'], [192, 198, 'INGREDIENT'],...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "To begin with the Lauki Yakhini Recipe, let's firs..." with entities "[[18, 23, 'INGREDIENT'], [56, 61, 'INGREDIENT'], [...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "To begin making Shakarkandi Ka Halwa Recipe(Sweet ..." with entities "[[44, 56, 'INGREDIENT'], [146, 150, 'INGREDIENT'],...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "To begin making the Sarson Chole Ka Saag Recipe, f..." with entities "[[224, 228, 'INGREDIENT'], [585, 590, 'INGREDIENT'...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "To begin making Seppakizhangu Roast (South Indian ..." with entities "[[56, 60, 'INGREDIENT'], [83, 87, 'INGREDIENT'], [...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# Losses: {'ner': np.float32(65233.93)}
# Iteration 2
# Losses: {'ner': np.float32(39954.656)}
# Iteration 3
# Losses: {'ner': np.float32(36568.15)}
# Iteration 4
# Losses: {'ner': np.float32(34626.848)}
# Iteration 5
# Losses: {'ner': np.float32(33231.32)}
# Iteration 6
# Losses: {'ner': np.float32(32244.283)}
# Iteration 7
# Losses: {'ner': np.float32(31620.39)}
# Iteration 8
# Losses: {'ner': np.float32(30830.018)}
# Iteration 9
# Losses: {'ner': np.float32(30408.396)}
# Iteration 10
# Losses: {'ner': np.float32(29717.562)}
# Model saved to ingredient_ner_model

# %%
import shutil
from google.colab import files  # <-- Add this

# Zip the folder
shutil.make_archive('/content/custom_ner_2', 'zip', '/content/ingredient_ner_model')
# Out:
# '/content/custom_ner_2.zip'
